# %% [markdown]
# # Visual Test Notebook
#
# This notebook is a lightweight manual smoke test for the plotting library.
# Each code cell renders one map product with a fixed timestamp so color tables,
# labels, and map overlays can be checked interactively.

# %%
from analysis.visual_lib import visual_lib_dict

import numpy as np
import matplotlib.pyplot as plt

# %%
# Use a broad CONUS domain for the default smoke test.
region_US = {
    "lon_s": -129,
    "lon_e": -64,
    "lat_s": 20,
    "lat_e": 55,
}

# This timestamp is reused by the map cells below so the products can be compared directly.
date = "20221224"
hour = 12

# %%
fig = visual_lib_dict["surface"](date, hour, region=region_US)

# %%
fig = visual_lib_dict["surfaceT"](date, hour, region=region_US)

# %%
fig = visual_lib_dict["map500"](date, hour, region=region_US)

# %%
region_lake = {"lon_s": -97.664, "lon_e": -64.310, "lat_s": 38.204, "lat_e": 51.591}
fig = visual_lib_dict["lakeEffect"](date, hour, region=region_lake)
